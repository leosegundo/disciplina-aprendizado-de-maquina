# %%
import numpy as np

# %%
np.random.seed(0)
x = np.random.rand(20)
x = (x*100).round(2)
x = np.resize(x,(20,1))
x
# Out:
# array([[ 54.88],
#        [ 71.52],
#        [ 60.28],
#        [ 54.49],
#        [ 42.37],
#        [ 64.59],
#        [ 43.76],
#        [ 89.18],
#        [ 96.37],
#        [ 38.34],
#        [ 79.17],
#        [ 52.89],
#        [ 56.8 ],
#        [ 92.56],
#        [  7.1 ],
#        [  8.71],
#        [  2.02],
#        [ 83.26],
#        [ 77.82],
#        [ 87.  ]])

# %%
def normalize(X):
    X_norm = np.copy(X)
    n_cols = X.shape[1]
    for i in range(n_cols):
        X_norm[:, i] = (X[:, i] - np.min(X[:, i])) / (np.max(X[:, i]) - np.min(X[:, i]))
    return X_norm

# %%
A = normalize(x)
A
# Out:
# array([[ 0.56025437],
#        [ 0.73661897],
#        [ 0.61748808],
#        [ 0.55612083],
#        [ 0.42766296],
#        [ 0.66316905],
#        [ 0.44239534],
#        [ 0.92379438],
#        [ 1.        ],
#        [ 0.38494966],
#        [ 0.81770005],
#        [ 0.53916269],
#        [ 0.58060413],
#        [ 0.95961844],
#        [ 0.05384208],
#        [ 0.0709062 ],
#        [ 0.        ],
#        [ 0.86104928],
#        [ 0.80339163],
#        [ 0.90068892]])
