# %% [markdown]
# ### Lista 11
#
# #### Aluno: Leodécio Braz
# #### Matricula: 377594

# %%
from sklearn import datasets 
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn import metrics
from sklearn import svm
from sklearn import naive_bayes

from sklearn import neighbors

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
# Out:
# /home/leodecio.segundo/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# ## Lista 7

# %%
kfold = KFold(n_splits=5)
kfold
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)

# %% [markdown]
# ## Regressão

# %%
#X,y = datasets.load_boston(return_X_y=True)
boston = datasets.load_boston(return_X_y=False)
X = boston.data
y = boston.target

# %%
def standardize(X):
    X_std = np.copy(X)
    n_cols = X.shape[1]
    for i in range(n_cols):
        X_std[:,i] = (X[:,i]-np.mean(X[:,i]))/np.std(X[:,i])
    return X_std

# %%
X_std = standardize(X)

# %% [markdown]
# ### Gradient Descent

# %%
modelSGD = linear_model.SGDRegressor()

# %%
RMSE = 0.0
MAE = 0.0

for train_index, test_index in kfold.split(X):
    X_train = X_std[train_index]
    X_test = X_std[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    modelSGD.fit(X_train,y_train)
    y_pred = modelSGD.predict(X_test)
    
    MAE += metrics.mean_absolute_error(y_test,y_pred)
    RMSE += metrics.mean_squared_error(y_test,y_pred)

MAE = MAE/5
RMSE =  np.sqrt(RMSE/5)
print("MAE: " + str(MAE) + " RMSE: " +str(RMSE))
# Out:
# MAE: 4.403268331159159 RMSE: 6.628189214523458
# /home/leodecio.segundo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %% [markdown]
# ###  Linear Regression

# %%
modelLR = linear_model.LinearRegression()

# %%
RMSE = 0.0
MAE = 0.0

for train_index, test_index in kfold.split(X):
    X_train = X_std[train_index]
    X_test = X_std[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    modelLR.fit(X_train,y_train)
    y_pred = modelLR.predict(X_test)
    
    MAE += metrics.mean_absolute_error(y_test,y_pred)
    RMSE += metrics.mean_squared_error(y_test,y_pred)

MAE = MAE/5
RMSE =  np.sqrt(RMSE/5)
print("MAE: " + str(MAE) + " RMSE: " +str(RMSE))
# Out:
# MAE: 4.256574046803887 RMSE: 6.101052666314071

# %% [markdown]
# ### KNN

# %%
modelKNN = neighbors.KNeighborsRegressor()

# %%
RMSE_ = 0.0
MAE_ = 0.0

for train_index, test_index in kfold.split(X):
    X_train = X_std[train_index]
    X_test = X_std[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    modelKNN.fit(X_train,y_train)
    y_pred = modelKNN.predict(X_test)
    
    MAE_ += metrics.mean_absolute_error(y_test,y_pred)
    RMSE_ += metrics.mean_squared_error(y_test,y_pred)

MAE = MAE_/5
RMSE =  np.sqrt(RMSE_/5)
print("MAE: " + str(MAE) + " RMSE: " +str(RMSE))
# Out:
# MAE: 3.7022620850320322 RMSE: 5.438388165234258

# %% [markdown]
# ### SVM

# %%
modelSVM = svm.SVR()

# %%
RMSE_ = 0.0
MAE_ = 0.0

for train_index, test_index in kfold.split(X):
    X_train = X_std[train_index]
    X_test = X_std[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    modelSVM.fit(X_train,y_train)
    y_pred = modelSVM.predict(X_test)
    
    MAE_ += metrics.mean_absolute_error(y_test,y_pred)
    RMSE_ += metrics.mean_squared_error(y_test,y_pred)

MAE = MAE_/5
RMSE =  np.sqrt(RMSE_/5)
print("MAE: " + str(MAE) + " RMSE: " +str(RMSE))
# Out:
# MAE: 4.223314829625372 RMSE: 6.588904420950123

# %% [markdown]
# ### Moldelo Final

# %%
model = neighbors.KNeighborsRegressor()

# %%
#XX = StandardScaler().fit_transform(X)

model.fit(X_std,y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
y_pred = model.predict(X_std)

# %%
MAE = metrics.mean_absolute_error(y,y_pred)
MSE = metrics.mean_squared_error(y,y_pred)
RMSE = np.sqrt(MSE)
print("MAE: " + str(MAE) + " RMSE: " +str(RMSE))
# Out:
# MAE: 2.13 RMSE: 3.3672833022994464

# %% [markdown]
# ## Classificação

# %%
breast = datasets.load_breast_cancer()
X = breast.data
y = breast.target

# %%
def normalize(X):
    y = np.copy(X)
    for i in range(X.shape[1]):
        y[:,i] = ((X[:,i] - np.min(X[:,i]))/(np.max(X[:,i]) - np.min(X[:,i])))
    return y

# %%
X_norm = normalize(X)

# %%
X_df = pd.DataFrame(X_norm)

# %%
def printRocCurve(y_test,y_score):
    for i in range (0,len(y_test)):
        metrics.roc_auc_score(y_test[i], y_score[i])
        fpr, tpr, _ = metrics.roc_curve(y_test[i], y_score[i])
        roc_auc = metrics.auc(fpr, tpr)
        plt.figure()
        plt.plot(fpr, tpr, color='darkorange',lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curve')
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
modelLRG = linear_model.LogisticRegression()

# %%
accuracy = 0.0
precision = 0.0
recall = 0.0
f1Measure = 0.0
auc = 0.0
y_testes = []
y_probas = []
i = 1
for train_index, test_index in kfold.split(X):
    X_train = X_norm[train_index]
    X_test = X_norm[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    y_testes.append(y_test)
    
    modelLRG.fit(X_train,y_train)
    y_pred = modelLRG.predict(X_test)
    
    conf_matriz = metrics.confusion_matrix(y_test,y_pred)
    
    y_score = modelLRG.predict_proba(X_test)[:,1]
    y_probas.append(y_score)
    
    accuracy += metrics.accuracy_score(y_test,y_pred)
    precision += metrics.precision_score(y_test,y_pred)
    recall += metrics.recall_score(y_test,y_pred)
    f1Measure += metrics.f1_score(y_test,y_pred)
    auc += metrics.roc_auc_score(y_test,y_pred)
    print(str(i) +': ' + str(conf_matriz))
    i=i+1
    

accuracy = accuracy/5
precision = precision/5
recall = recall/5
f1Measure = f1Measure/5
auc = auc/5
print("accuracy: " + str(accuracy) + "\nprecision: " +str(precision)+ "\nrecall: " +str(recall)
     + "\nF1-Measure: " +str(f1Measure) + "\nAUC: " +str(auc))

printRocCurve(y_testes,y_probas)
# Out:
# 1: [[58 10]
#  [ 1 45]]
# 2: [[41  8]
#  [ 0 65]]
# 3: [[36  4]
#  [ 0 74]]
# 4: [[28  1]
#  [ 1 84]]
# 5: [[26  0]
#  [ 1 86]]
# accuracy: 0.9543704393727681
# precision: 0.9291092039843047
# recall: 0.9910003821618603
# F1-Measure: 0.9578514504482583
# AUC: 0.951019502253675

# %% [markdown]
# ### KNN

# %%
modelKNN = neighbors.KNeighborsClassifier()

# %%
accuracy = 0.0
precision = 0.0
recall = 0.0
f1Measure = 0.0
auc = 0.0
y_testes = []
y_probas = []
i = 1
for train_index, test_index in kfold.split(X):
    X_train = X_norm[train_index]
    X_test = X_norm[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    y_testes.append(y_test)
    
    modelKNN.fit(X_train,y_train)
    y_pred = modelKNN.predict(X_test)
    
    conf_matriz = metrics.confusion_matrix(y_test,y_pred)
    
    y_score = modelKNN.predict_proba(X_test)[:,1]
    y_probas.append(y_score)
    
    accuracy += metrics.accuracy_score(y_test,y_pred)
    precision += metrics.precision_score(y_test,y_pred)
    recall += metrics.recall_score(y_test,y_pred)
    f1Measure += metrics.f1_score(y_test,y_pred)
    auc += metrics.roc_auc_score(y_test,y_pred)
    print(str(i) +': ' + str(conf_matriz))
    i=i+1
    

accuracy = accuracy/5
precision = precision/5
recall = recall/5
f1Measure = f1Measure/5
auc = auc/5
print("accuracy: " + str(accuracy) + "\nprecision: " +str(precision)+ "\nrecall: " +str(recall)
     + "\nF1-Measure: " +str(f1Measure) + "\nAUC: " +str(auc))

printRocCurve(y_testes,y_probas)
# Out:
# 1: [[61  7]
#  [ 2 44]]
# 2: [[46  3]
#  [ 0 65]]
# 3: [[36  4]
#  [ 0 74]]
# 4: [[27  2]
#  [ 0 85]]
# 5: [[26  0]
#  [ 3 84]]
# accuracy: 0.9631113181183046
# precision: 0.9488713787902429
# recall: 0.9844077961019491
# F1-Measure: 0.9658345095536731
# AUC: 0.9588907797001859

# %% [markdown]
# ### Naive Bayes

# %%
modelNVB = naive_bayes.GaussianNB()

# %%
accuracy = 0.0
precision = 0.0
recall = 0.0
f1Measure = 0.0
auc = 0.0
y_testes = []
y_probas = []
i = 1
for train_index, test_index in kfold.split(X):
    X_train = X_norm[train_index]
    X_test = X_norm[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    y_testes.append(y_test)
    
    modelNVB.fit(X_train,y_train)
    y_pred = modelNVB.predict(X_test)
    
    conf_matriz = metrics.confusion_matrix(y_test,y_pred)
    
    y_score = modelNVB.predict_proba(X_test)[:,1]
    y_probas.append(y_score)
    
    accuracy += metrics.accuracy_score(y_test,y_pred)
    precision += metrics.precision_score(y_test,y_pred)
    recall += metrics.recall_score(y_test,y_pred)
    f1Measure += metrics.f1_score(y_test,y_pred)
    auc += metrics.roc_auc_score(y_test,y_pred)
    print(str(i) +': ' + str(conf_matriz))
    i=i+1
    

accuracy = accuracy/5
precision = precision/5
recall = recall/5
f1Measure = f1Measure/5
auc = auc/5
print("accuracy: " + str(accuracy) + "\nprecision: " +str(precision)+ "\nrecall: " +str(recall)
     + "\nF1-Measure: " +str(f1Measure) + "\nAUC: " +str(auc))

printRocCurve(y_testes,y_probas)
# Out:
# 1: [[58 10]
#  [ 4 42]]
# 2: [[43  6]
#  [ 2 63]]
# 3: [[37  3]
#  [ 3 71]]
# 4: [[27  2]
#  [ 1 84]]
# 5: [[24  2]
#  [ 7 80]]
# accuracy: 0.9296848315478963
# precision: 0.9265098375113417
# recall: 0.9499018461907605
# F1-Measure: 0.9372205053092115
# AUC: 0.9259112833668098

# %% [markdown]
# ### SVM

# %%
modelSVM = svm.SVC(probability=True)

# %%
accuracy = 0.0
precision = 0.0
recall = 0.0
f1Measure = 0.0
auc = 0.0
y_testes = []
y_probas = []
i = 1
for train_index, test_index in kfold.split(X):
    X_train = X_norm[train_index]
    X_test = X_norm[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    y_testes.append(y_test)
    
    modelSVM.fit(X_train,y_train)
    y_pred = modelSVM.predict(X_test)
    
    conf_matriz = metrics.confusion_matrix(y_test,y_pred)
    
    y_score = modelSVM.predict_proba(X_test)[:,1]
    y_probas.append(y_score)
    
    accuracy += metrics.accuracy_score(y_test,y_pred)
    precision += metrics.precision_score(y_test,y_pred)
    recall += metrics.recall_score(y_test,y_pred)
    f1Measure += metrics.f1_score(y_test,y_pred)
    auc += metrics.roc_auc_score(y_test,y_pred)
    print(str(i) +': ' + str(conf_matriz))
    i=i+1
    

accuracy = accuracy/5
precision = precision/5
recall = recall/5
f1Measure = f1Measure/5
auc = auc/5
print("accuracy: " + str(accuracy) + "\nprecision: " +str(precision)+ "\nrecall: " +str(recall)
     + "\nF1-Measure: " +str(f1Measure) + "\nAUC: " +str(auc))

printRocCurve(y_testes,y_probas)
# Out:
# 1: [[52 16]
#  [ 0 46]]
# 2: [[40  9]
#  [ 0 65]]
# 3: [[36  4]
#  [ 0 74]]
# 4: [[27  2]
#  [ 0 85]]
# 5: [[24  2]
#  [ 1 86]]
# accuracy: 0.9403043005744449
# precision: 0.9046632064985791
# recall: 0.9977011494252874
# F1-Measure: 0.9464034193639435
# AUC: 0.9323649565927168

# %% [markdown]
# ### Modelo Final

# %%
modelKNN = neighbors.KNeighborsClassifier()

# %%
modelKNN.fit(X_norm,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred = modelKNN.predict(X_norm)

# %%
print(metrics.accuracy_score(y,y_pred))
# Out:
# 0.9789103690685413

# %% [markdown]
# # Lista 10

# %%
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier

# %%
def regressao(model,X_,y_):
    mae = 0.0
    rmse = 0.0
    for train_index,test_index in kfold.split(X):
        X_train = X_[train_index]
        X_test = X_[test_index]
        y_train = y[train_index]
        y_test = y[test_index]
        
        model.fit(X_train, y_train)
        
        y_pred = model.predict(X_test) 
        
        mae += metrics.mean_absolute_error(y_test,y_pred)
        rmse += np.sqrt(metrics.mean_squared_error(y_test,y_pred))
    print("MAE: "+ str((mae/5)) + "\nRMSE: "+ str((rmse/5)))

# %%
def classification(model,X_,y_):
    accuracy = 0.0
    recall = 0.0
    f1 = 0.0
    auc = 0.0
    for train_index, test_index in kfold.split(X):
        X_train = X_[train_index]
        y_train = y_[train_index]
        X_test = X_[test_index]
        y_test = y_[test_index]
        
        
        model.fit(X_train,y_train)
        y_pred = model.predict(X_test)
        
        accuracy += metrics.accuracy_score(y_test,y_pred)
        recall += metrics.recall_score(y_test,y_pred)
        f1 += metrics.f1_score(y_test,y_pred)
        auc += metrics.roc_auc_score(y_test,y_pred)
    print("accuracy: " + str((accuracy/5)) + "\nrecall: "+ str((recall/5)) +
          "\nf1: "+ str((f1/5)) + "\nauc: "+ str((auc/5)))

# %% [markdown]
# #### DecisionTreeRegressor

# %%
dTReg = DecisionTreeRegressor(random_state=0)
#dTReg2 = DecisionTreeRegressor(random_state=0)
#dTReg3 = DecisionTreeRegressor(random_state=0)

# %%
regressao(dTReg,X_norm,y)
# Out:
# MAE: 0.09677068778140041
# RMSE: 0.30458797436193175

# %% [markdown]
# ####  RandomForestRegressor

# %%
rFReg1 = RandomForestRegressor(n_estimators=50,max_depth=3)
rFReg2 = RandomForestRegressor(n_estimators=100,max_depth=5)
rFReg3 = RandomForestRegressor(n_estimators=200,max_depth=7)

# %%
regressao(rFReg1,X_norm,y)
# Out:
# MAE: 0.0924726032494094
# RMSE: 0.2022669404645178

# %%
regressao(rFReg2,X_norm,y)
# Out:
# MAE: 0.08694478236887618
# RMSE: 0.19799580723672308

# %%
regressao(rFReg3,X_norm,y)
# Out:
# MAE: 0.08654120373615357
# RMSE: 0.19595913584482708

# %% [markdown]
# #### GradientBoostingRegressor

# %%
gBReg1 = GradientBoostingRegressor(learning_rate=0.1,n_estimators=50,max_depth=3)
gBReg2 = GradientBoostingRegressor(learning_rate=0.05,n_estimators=100,max_depth=5)
gBReg3 = GradientBoostingRegressor(learning_rate=0.01,n_estimators=200,max_depth=7)

# %%
regressao(gBReg1,X_norm,y)
# Out:
# MAE: 0.08846213002743164
# RMSE: 0.20175955502484183

# %%
regressao(gBReg2,X_norm,y)
# Out:
# MAE: 0.08079744274786257
# RMSE: 0.233512516579371

# %%
regressao(gBReg3,X_norm,y)
# Out:
# MAE: 0.14599435059227184
# RMSE: 0.27033778812945386

# %% [markdown]
# #### DecisionTreeClassifier

# %%
dTClas = DecisionTreeClassifier(random_state=0)

# %%
classification(dTClas,X_norm,y)
# Out:
# accuracy: 0.9032293122185996
# recall: 0.9105155664799373
# f1: 0.9172287772287773
# auc: 0.9078610818538438

# %% [markdown]
# #### RandomForestRegressor

# %%
rFClass1 = RandomForestClassifier(n_estimators=50, max_depth=3)
rFClass2 = RandomForestClassifier(n_estimators=100, max_depth=5)
rFClass3 = RandomForestClassifier(n_estimators=200, max_depth=7)

# %%
classification(rFClass1,X_norm,y)
# Out:
# accuracy: 0.9490762303990063
# recall: 0.9734939769934037
# f1: 0.9529628938635
# auc: 0.9476128228941214

# %%
classification(rFClass2,X_norm,y)
# Out:
# accuracy: 0.9543238627542309
# recall: 0.9748189706051951
# f1: 0.9585942621867701
# auc: 0.9532573124971361

# %%
classification(rFClass3,X_norm,y)
# Out:
# accuracy: 0.9543393882937432
# recall: 0.9724660294287245
# f1: 0.9591879709604996
# auc: 0.9539493081282796

# %% [markdown]
# ####  GradientBoostingClassifier

# %%
gBClass1 = GradientBoostingClassifier(learning_rate=0.1,n_estimators=50,max_depth=3)
gBClass2 = GradientBoostingClassifier(learning_rate=0.05,n_estimators=100,max_depth=5)
gBClass3 = GradientBoostingClassifier(learning_rate=0.01,n_estimators=200,max_depth=7)

# %%
classification(gBClass1,X_norm,y)
# Out:
# accuracy: 0.9490917559385188
# recall: 0.964987189663087
# f1: 0.9537162735145541
# auc: 0.9486282555923996

# %%
classification(gBClass2,X_norm,y)
# Out:
# accuracy: 0.9367334264865704
# recall: 0.9625087187358993
# f1: 0.9453439281978717
# auc: 0.9419460206478462

# %%
classification(gBClass3,X_norm,y)
# Out:
# accuracy: 0.9138487812451483
# recall: 0.9348103421690158
# f1: 0.9258845242378332
# auc: 0.9150264769012644
